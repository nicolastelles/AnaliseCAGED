# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
colunas = ['competencia','regiao','uf','secao','subclasse','saldomovimentacao','cbo2002ocupacao','categoria','graudeinstrucao','idade','racacor','sexo','tipomovimentacao','tipodedeficiencia','salario','indicadoraprendiz']
df = pd.read_csv(r'C:\Users\Pichau\Documents\Fatec\3Semestre\Estrutura_de_dados\CAGED\CAGED2020.csv', encoding = 'iso-8859-1', delimiter=";", low_memory=False, usecols= colunas)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-5fcab7870418> in <module>
#       1 colunas = ['competencia','regiao','uf','secao','subclasse','saldomovimentacao','cbo2002ocupacao','categoria','graudeinstrucao','idade','racacor','sexo','tipomovimentacao','tipodedeficiencia','salario','indicadoraprendiz']
# ----> 2 df = pd.read_csv(r'C:\Users\Pichau\Documents\Fatec\3Semestre\Estrutura_de_dados\CAGED\CAGED2020.csv', encoding = 'iso-8859-1', delimiter=";", low_memory=False, usecols= colunas)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24753706 entries, 0 to 24753705
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   competencia        object
#  1   regiao             float64
#  2   uf                 float64
#  3   secao              object
#  4   subclasse          float64
#  5   saldomovimentacao  float64
#  6   cbo2002ocupacao    float64
#  7   categoria          float64
#  8   graudeinstrucao    float64
#  9   idade              float64
#  10  racacor            float64
#  11  sexo               float64
#  12  tipomovimentacao   float64
#  13  tipodedeficiencia  float64
#  14  salario            float64
#  15  indicadoraprendiz  float64
# dtypes: float64(14), object(2)
# memory usage: 3.0+ GB

# %%
df['tipomovimentacao'] = pd.to_numeric(df['tipomovimentacao'])

# %%
df['tipomovimentacao'] = df['tipomovimentacao'].map({10.0:'Admissão por primeiro emprego', 20.0:'Admissão por reemprego', 25.0:'Admissão por contrato trabalho prazo determinado', 31.0:'Desligamento por demissão sem justa causa', 32.0:'Desligamento por demissão com justa causa', 33.0:'Culpa Recíproca', 35.0:'Admissão por reintegração', 40.0:'Desligamento a pedido', 43.0:'Término contrato trabalho prazo determinado', 45.0:'Desligamento por Término de contrato', 50.0:'Desligamento por aposentadoria', 60.0:'Desligamento por morte', 70.0:'Admissão por transferência', 80.0:'Desligamento por transferência', 90.0:'Desligamento por Acordo entre empregado e empregador', 98.0:'Desligamento de Tipo Ignorado', 99.0:'Não Identificado'}, na_action=None)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,7))
sns.countplot(y='tipomovimentacao', data=df, hue= 'racacor')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed845f329a1b> in <module>
# ----> 1 sns.set_style('darkgrid')
#       2 plt.figure(figsize=(12,7))
#       3 sns.countplot(y='tipomovimentacao', data=df, hue= 'racacor')
#
# NameError: name 'sns' is not defined

# %%
df['Sexo'] = df['Sexo'].apply(lambda x: "MASCULINO" if x == 1 else "FEMININO")

# %%
sns.countplot(x='tipomovimentacao', data=df3, hue ='sexo')
# Out:
# <AxesSubplot:xlabel='tipomovimentacao', ylabel='count'>

# %%
"sns.countplot(x='Sexo', data=df, hue ='Salario Mensal')"

# %%
"sns.countplot(x='Salario Mensal', data=df, hue ='Sexo')"

# %%
teste = df.groupby(by=['Grau Instrucao','Sexo']).count()['Salario Mensal'].unstack()
plt.figure(figsize=(12,5))
sns.clustermap(teste,cmap='viridis')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24753706 entries, 0 to 24753705
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   competencia        object
#  1   regiao             float64
#  2   uf                 float64
#  3   secao              object
#  4   subclasse          float64
#  5   saldomovimentacao  float64
#  6   cbo2002ocupacao    float64
#  7   categoria          float64
#  8   graudeinstrucao    float64
#  9   idade              float64
#  10  racacor            float64
#  11  sexo               float64
#  12  tipomovimentacao   float64
#  13  tipodedeficiencia  float64
#  14  salario            float64
#  15  indicadoraprendiz  float64
# dtypes: float64(14), object(2)
# memory usage: 3.0+ GB

# %%
df3['tipomovimentacao'].value_counts().head(20)
# Out:
# 20.0    11410913
# 31.0     7045716
# 40.0     2934669
# 43.0     1985980
# 10.0      786524
# 32.0      152890
# 90.0      139979
# 45.0      100730
# 99.0       59196
# 60.0       54590
# 25.0       37809
# 33.0       18915
# 35.0       13778
# 50.0       11370
# 98.0         646
# Name: tipomovimentacao, dtype: int64
